# %%
import altair as alt # https://altair-viz.github.io/user_guide/interactions.html
import datapane as dp # https://www.youtube.com/watch?v=_KS_yZBI71s&ab_channel=Datapane
import pandas as pd

# %%
buildtimes_df = pd.read_csv("new_buildtimes.csv")
buildtimes_df
# Out:
#                                       job_name  build_number  \
# 0      Rci__nightly-release_ubuntu_jammy_amd64           793
# 1      Rci__nightly-release_ubuntu_jammy_amd64           793
# 2      Rci__nightly-release_ubuntu_jammy_amd64           793
# 3      Rci__nightly-release_ubuntu_jammy_amd64           793
# 4      Rci__nightly-release_ubuntu_jammy_amd64           793
# ...                                        ...           ...
# 10342  Rci__nightly-release_ubuntu_jammy_amd64           807
# 10343  Rci__nightly-release_ubuntu_jammy_amd64           807
# 10344  Rci__nightly-release_ubuntu_jammy_amd64           807
# 10345  Rci__nightly-release_ubuntu_jammy_amd64           807
# 10346  Rci__nightly-release_ubuntu_jammy_amd64           807
#
#                                        section_name section_type  \
# 0                             Check free disk space      section
# 1                                          cpu info      section
# ...

# %%
dp.DataTable(buildtimes_df)

# %%
section_df = buildtimes_df.query("section_type == 'subsection' and section_name == 'build workspace in isolation'")
section_df
# Out:
#                                      job_name  build_number  \
# 25    Rci__nightly-release_ubuntu_jammy_amd64           806
# 732   Rci__nightly-release_ubuntu_jammy_amd64           799
# 1443  Rci__nightly-release_ubuntu_jammy_amd64           802
# 1801  Rci__nightly-release_ubuntu_jammy_amd64           805
# 2474  Rci__nightly-release_ubuntu_jammy_amd64           800
# 3129  Rci__nightly-release_ubuntu_jammy_amd64           804
# 3848  Rci__nightly-release_ubuntu_jammy_amd64           797
# 4551  Rci__nightly-release_ubuntu_jammy_amd64           793
# 5253  Rci__nightly-release_ubuntu_jammy_amd64           796
# 5998  Rci__nightly-release_ubuntu_jammy_amd64           807
# 6753  Rci__nightly-release_ubuntu_jammy_amd64           801
# 7402  Rci__nightly-release_ubuntu_jammy_amd64           803
# 8142  Rci__nightly-release_ubuntu_jammy_amd64           795
# 8886  Rci__nightly-release_ubuntu_jammy_amd64           794
# 9571  Rci__nightly-release_ubuntu_jammy_amd64           798
#
# ...

# %%
options = buildtimes_df["section_name"].unique()
# labels = [option + ' ' for option in options]

input_dropdown = alt.binding_select(options=options, name="Section Name:")
selection = alt.selection_point(fields=["section_name"], bind=input_dropdown)

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(buildtimes_df).mark_line().encode(
    x='build_number',
    y='duration_seconds',
).add_params(
    selection
).transform_filter(
    selection
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(section_df).mark_line().encode(
    x='build_number',
    y='duration_seconds'
)
# Out:
# alt.Chart(...)
